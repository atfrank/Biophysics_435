# %%
# %%capture
from annealing import *
from machine_learning import *

# %%
_,_,_ = plot_muller_potential()

# %%
# load dataset
y, X = get_dataset(delta = 0.0125)
model = train_model(y, X, verbose=1, epochs=10000, batch_size=1000, loss='mean_squared_logarithmic_error')
# Out:
# 2 3
# Epoch 1/10000
# 67200/67200 [==============================] - 1s 11us/step - loss: 11.0703
# Epoch 2/10000
# 67200/67200 [==============================] - 0s 3us/step - loss: 10.2220
# Epoch 3/10000
# 67200/67200 [==============================] - 0s 3us/step - loss: 9.7389
# Epoch 4/10000
# 67200/67200 [==============================] - 0s 3us/step - loss: 9.4827
# Epoch 5/10000
# 67200/67200 [==============================] - 0s 3us/step - loss: 9.3292
# Epoch 6/10000
# 67200/67200 [==============================] - 0s 3us/step - loss: 9.2248
# Epoch 7/10000
# 67200/67200 [==============================] - 0s 3us/step - loss: 9.1479
# Epoch 8/10000
# 67200/67200 [==============================] - 0s 3us/step - loss: 9.0886
# Epoch 9/10000
# 67200/67200 [==============================] - 0s 3us/step - loss: 9.0400
# Epoch 10/10000
# 67200/67200 [==============================] - 0s 3us/step - loss: 8.9982
# Epoch 11/10000
# ...

# %%
_,_,_ = plot_muller_potential(title = "Actual Muller Potential")
_,_,_ = plot_muller_potential_ml(model, title = "Predicted Muller Potential")
